# %% [markdown]
# ## Promising pairs
# ### Spain
# * [Ebro foods - Orkla](#Ebro-foods-(spain)---Orkla)
# * [Acerinox, S.A - STB / NOD](#Acerinox,-S.A---STB)
#
# ### Germany
# * [Brenntag - Yara / Gjensidige / Telenor / Orkla](#Brenntag-(Germany)---Yara)
# * [Wacker Chemie - Elkem](#Wacker-Chemie---Elkem)
#
# ### France
# * [Danone - Orkla](#Danone---Orkla)
#
# ### Russia
# * [Gazprom (Russia) - Yara](#Gazprom-(Russia)---Yara)

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Functionality

# %%
def plot_pair_norm(tickers: str, start: str) -> plt.subplot:
    df_ = yf.download(tickers, start=start)['Close']
    df_.fillna(method='bfill', inplace=True)
    df_ = df_ / df_.iloc[0]
    df_.plot(figsize=(12,6))
    
    
def z_score(series):
    """
    Calculates z-scores for a given timeseries
    
    Parameters
    -----------
    series : Pandas timeseries
        time series
        
    Returns
    -----------
    Pandas timeseries
        z-scores of series
    """
    return (series - series.mean()) / np.std(series)


def plot_z_score(S1, S2, cuttoff : float = 1.6, figsize=(12,6)):
    
    
    """
    Function for plotting z-score, including a lower and upper band s
    
    Parameters
    -----------
    
    S1, S2 : pandas Series
        Series of price data (Close)
        
    start, end: string
        start / end of the time interval
    
    Returns
    -----------
    matplotlib figure
        visualisation of the z-score, including a upper and lower band
    
    """
    fig = plt.figure()
    ratio = S1 / S2
    z_score(ratio).plot(figsize=figsize, label = 'z-score')
    
    plt.axhline(z_score(ratio).mean(), color='k', linestyle = '-.', alpha=0.9, label='z-score mean')
    plt.axhline(cuttoff, color='red', linestyle = '--', alpha=0.9, label = 'upper border')
    plt.axhline(-cuttoff, color='green', linestyle = '--', alpha=0.9, label = ' lower border')
    
    plt.xlabel('')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Ebro foods (spain) - Orkla

# %%
plot_pair_norm('ebro.mc ork.ol', start='2012-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('ebro.mc ork.ol', start='2012-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1], cuttoff=1.6)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ### Brenntag (Germany) - Yara

# %%
plot_pair_norm('BNR.DE yar.OL', '2012-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('BNR.DE yar.OL', start='2012-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1], cuttoff=1.8)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
plot_pair_norm('BNR.DE gjf.OL', '2012-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('BNR.DE gjf.OL', start='2012-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1], cuttoff=1.5)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ### Wacker Chemie - Elkem

# %%
plot_pair_norm('WCH.DE ELK.OL', '2019-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('WCH.DE ELK.OL', start='2018-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1], cuttoff=1.5)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ## Spain
# ### Acerinox, S.A - STB

# %%
plot_pair_norm('acx.mc stb.ol', '2012-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('acx.mc stb.ol', start='2012-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1])
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ### Danone - Orkla

# %%
plot_pair_norm('bn.pa ork.ol', start='2012-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('bn.pa ork.ol', start='2012-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1])
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ### Gazprom (Russia) - Yara

# %%
plot_pair_norm('gazp.me yar.ol', start='2012-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = yf.download('gazp.me yar.ol', start='2012-01-01')['Close']
plot_z_score(df.iloc[:,0], df.iloc[:,1])
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [10, 12, 13, 17] 
  
b = [30, 40]
  
a.extend(b)
  
print(a)
# Out:
# [10, 12, 13, 17, 30, 40]
